# %%
import json
f=open('chap_6_ans.txt',encoding="utf8") #,

#creating an instance s which holds all the content of the text file( sample.txt)
s=f.read()

# %% [markdown]
# ## Questions

# %%
st=0
e=0
li=[]
liq=[]
sol='?'
count=1
for i in range(1,81):
    start = s.find(str(count)+'.')
    end=s.find('(d)', start)
    #e1=s.find(' ', end)
    if 'PASSAGE -' in s[end:]:
        fd=s.find('PASSAGE -',end)
    else:
        fd=s.find(str(count+1),end)
    m=s[start:fd]
    x=m.split('\n')
    li.append(x)
    #liq.append(s[e1+1:en])
    #print(s[start:fd])
    
    #print(s[e1:en])
    count+=1

# %% [markdown]
# ## Answer

# %%
liq=[]
count=1
for i in range(1,81):
    start = s.find(str(count)+'.')
    end=s.find(str(count+1), start)
    m=s[start:end]
    x=m.split('\n')
    liq.append(x)
    #liq.append(s[e1+1:en])
    print(s[start:end])
    #break
    #print(s[e1:en])
    count+=1

# %% [markdown]
# ## Dumping the question
#   * do change filename

# %%
o = open("UPSC CSAT Paper-2 (2015)_question.json", "w") 
json.dump(li, o, indent = 4, sort_keys = False) 
o.close()

# %% [markdown]
# ## Dumping the ans
#   * do change filename

# %%
o = open("Interpersonal & Communication Skills_answers.json", "w") 
json.dump(linew, o, indent = 4, sort_keys = False) 
o.close()

# %%
#for personality tesr info
liq=[]
count=1
for i in range(1,59):
    start = s.find(str(count)+'.')
    end=s.find(str(count+1), start)
    m=s[start:end]
    x=m.split('\n')
    liq.append(x)
    #liq.append(s[e1+1:en])
    print(s[start:end])
    #break
    #print(s[e1:en])
    count+=1

# %%
#Interpersonal & Communication Skills.txt
j=1
linew=[]
liq=[]
sol='?'
count=1
for i in range(1,45):
    start = s.find(str(i)+'.')
    end=s.find('(d)', start)
    #e1=s.find(' ', end)
    #if str(i+1) in s[end:]:
    fd=s.find(str(i+1)+'.',end)
        
   # elif 'SITUATION {}:'.format(j) in s[end:]:
    #    fd=s.find('SITUATION {}:'.format(j),end)
     #   j+=1
    m=s[start:fd]
    x=m.split('\n')
    linew.append(x)
    #liq.append(s[e1+1:en])
    print(s[start:fd])
    #print(count)
    #print(s[e1:en])
    #count+=1
# Out:
# 1. (a) The maximum diversity is found in tropical rain forests.
# Tropical forests are some of the richest areas on Earth.
# About 80% of the world’s documented species can be found
# in tropical rainforests.
# 2. (d) Eucalyptus is considered as environmental hazard due to
# various reasons. Eucalyptus is responsible for replacing
# indigenous forests in several parts of the world, depleting
# join telegram https://t.me/reetmaterials2
# food and shelter sources and therefore affecting animals
# and birds. Growing Eucalyptus in low rainfall areas may
# cause adverse environmental impacts due to competition
# for water with other species.
# 3. (c) Destruction of habitat is one of the main reasons for
# biodiversity decline.
# 4. (a) Biosphere reserves provides in-situ conservation of genetic
# resources in natural populations of both flora or fauna . It is
# actually on-site conservation of genetic resources in their
# natural environment.
# ...

# %%
for i in s:
    print(i,end="")

# %%
#Interpersonal & Communication Skills_answers
j=1
linew=[]
liq=[]
count=1
for i in range(1,45):
    start = s.find(str(i)+'.')
    #end=s.find(')', start)
    #end=start+4
    fd=s.find(str(i+1)+'.',start)
        
   # elif 'SITUATION {}:'.format(j) in s[end:]:
    #    fd=s.find('SITUATION {}:'.format(j),end)
     #   j+=1
    m=s[start:fd]
    x=m.split('\n')
    linew.append(x)
    #liq.append(s[e1+1:en])
    print(s[start:fd])
    #print(count)
    #print(s[e1:en])
    #count+=1
# Out:
# 1. (a) The maximum diversity is found in tropical rain forests.
# Tropical forests are some of the richest areas on Earth.
# About 80% of the world’s documented species can be found
# in tropical rainforests.
#
# 2. (d) Eucalyptus is considered as environmental hazard due to
# various reasons. Eucalyptus is responsible for replacing
# indigenous forests in several parts of the world, depleting
# join telegram https://t.me/reetmaterials2
# food and shelter sources and therefore affecting animals
# and birds. Growing Eucalyptus in low rainfall areas may
# cause adverse environmental impacts due to competition
# for water with other species.
#
# 3. (c) Destruction of habitat is one of the main reasons for
# biodiversity decline.
#
# 4. (a) Biosphere reserves provides in-situ conservation of genetic
# resources in natural populations of both flora or fauna . It is
# actually on-site conservation of genetic resources in their
# natural environment.
#
# ...

# %%
liq=[]
for i in range(1,551):
    start = s.find(str(i)+'.')
    #end=s.find('(d)', start)
   
    fd=s.find(str(i+1)+'.',start)
    m=s[start:fd]
    if "Codes" in m:
        continue
    else:
        x=m.split('\n')
        liq.append(x)
    #liq.append(s[e1+1:en])
    print(m)
    start=0
    end=0
    #break
# Out:
# 1. (b) Guru Shikhar, a peak in the Arbuda Mountains of
# Rajasthan, is the highest point of the Aravali Range. It rises to
# an elevation of 1,722 metres.
# Doddabetta is the highest mountain in the Nilgiri Hills at 2,637
# metres. There is a reserved forest area around the peak. It is 9
# km from Ooty, on the Ooty-Kotagiri Road in the Nilgiris district of
# Tamil Nadu, India.
# Anamudi or Anai Mudi is a mountain located in the Indian state of
# Kerala. It is the highest peak in the Western Ghats and South
# India, at an elevation of 2,695 metres, and a topographic
# prominence of 2,479 metres.
# Mount Dhupgarh or Dhoopgarh is the highest point in the
# Satpura Range and in Madhya Pradesh, India. Located in
# Pachmarhi, it has an elevation of 1,350 metres.
#
# 2. (d) India is located in eastern part of Northern hemisphere.
#
# 3. (a) High and dry winds would blow outwards from this high
# pressure area when a high pressure develops over the North –
# Western part of India.
#
# ...

# %%
o = open("chapter_6_ans.json", "w") 
json.dump(linew, o, indent = 4, sort_keys = False) 
o.close()

# %%
liq
# Out:
# [['1. (b) Guru Shikhar, a peak in the Arbuda Mountains of',
#   'Rajasthan, is the highest point of the Aravali Range. It rises to',
#   'an elevation of 1,722 metres.',
#   'Doddabetta is the highest mountain in the Nilgiri Hills at 2,637',
#   'metres. There is a reserved forest area around the peak. It is 9',
#   'km from Ooty, on the Ooty-Kotagiri Road in the Nilgiris district of',
#   'Tamil Nadu, India.',
#   'Anamudi or Anai Mudi is a mountain located in the Indian state of',
#   'Kerala. It is the highest peak in the Western Ghats and South',
#   'India, at an elevation of 2,695 metres, and a topographic',
#   'prominence of 2,479 metres.',
#   'Mount Dhupgarh or Dhoopgarh is the highest point in the',
#   'Satpura Range and in Madhya Pradesh, India. Located in',
#   'Pachmarhi, it has an elevation of 1,350 metres.',
#   ''],
#  ['2. (d) India is located in eastern part of Northern hemisphere.', ''],
#  ['3. (a) High and dry winds would blow outwards from this high',
# ...

# %%
linew
# Out:
# [['1. (a) The maximum diversity is found in tropical rain forests.',
#   'Tropical forests are some of the richest areas on Earth.',
#   'About 80% of the world’s documented species can be found',
#   'in tropical rainforests.',
#   ''],
#  ['2. (d) Eucalyptus is considered as environmental hazard due to',
#   'various reasons. Eucalyptus is responsible for replacing',
#   'indigenous forests in several parts of the world, depleting',
#   'join telegram https://t.me/reetmaterials2',
#   'food and shelter sources and therefore affecting animals',
#   'and birds. Growing Eucalyptus in low rainfall areas may',
#   'cause adverse environmental impacts due to competition',
#   'for water with other species.',
#   ''],
#  ['3. (c) Destruction of habitat is one of the main reasons for',
#   'biodiversity decline.',
#   ''],
#  ['4. (a) Biosphere reserves provides in-situ conservation of genetic',
#   'resources in natural populations of both flora or fauna . It is',
# ...
